# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ### Reading DataSet (check format of Dataset like csv,xlsx...)

# %%
df = pd.read_csv("/Users/pavansai/desktop1/Python/EDA/csv/cubic_zirconia.csv")
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table     x     y  \
# 0               1   0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29
# 1               2   0.33    Premium     G      IF   60.8   58.0  4.42  4.46
# 2               3   0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12
# 3               4   0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80
# 4               5   0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43
# ...           ...    ...        ...   ...     ...    ...    ...   ...   ...
# 26962       26963   1.11    Premium     G     SI1   62.3   58.0  6.61  6.52
# 26963       26964   0.33      Ideal     H      IF   61.9   55.0  4.44  4.42
# 26964       26965   0.51    Premium     E     VS2   61.7   58.0  5.12  5.15
# 26965       26966   0.27  Very Good     F    VVS2   61.8   56.0  4.19  4.20
# 26966       26967   1.25    Premium     J     SI1   62.0   58.0  6.90  6.88
#
#           z  price
# 0      2.66    499
# 1      2.70    984
# 2      3.78   6289
# 3      2.96   1082
# 4      2.65    779
# ...     ...    ...
# 26962  4.09   5408
# 26963  2.74   1114
# 26964  3.17   1656
# 26965  2.60    682
# 26966  4.27   5166
#
# [26967 rows x 11 columns]

# %% [markdown]
# ### Viewing DataSet
# ### Check what are dependent and indepndent columns

# %%
df.head()
# Out:
#    Unnamed: 0  carat        cut color clarity  depth  table     x     y     z  \
# 0           1   0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66
# 1           2   0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70
# 2           3   0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78
# 3           4   0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96
# 4           5   0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65
#
#    price
# 0    499
# 1    984
# 2   6289
# 3   1082
# 4    779

# %% [markdown]
# ## Gives the inforamtion on data set.
#
# ### 1. How many columns are present.
# ### 2. What are the different datatypes that are present in different columns[Numerical or Categorical]
# ### 3. Check the number of entries present (this many rows are present in the dataset).
# ### 4. If there are any null values present in the data set.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26967 entries, 0 to 26966
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  26967 non-null  int64
#  1   carat       26967 non-null  float64
#  2   cut         26967 non-null  object
#  3   color       26967 non-null  object
#  4   clarity     26967 non-null  object
#  5   depth       26270 non-null  float64
#  6   table       26967 non-null  float64
#  7   x           26967 non-null  float64
#  8   y           26967 non-null  float64
#  9   z           26967 non-null  float64
#  10  price       26967 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 2.3+ MB

# %% [markdown]
# ### Unnamed column consits of all unq values it is not much informative so we will drop

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)
df
# Out:
#        carat        cut color clarity  depth  table     x     y     z  price
# 0       0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66    499
# 1       0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70    984
# 2       0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78   6289
# 3       0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96   1082
# 4       0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65    779
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 26962   1.11    Premium     G     SI1   62.3   58.0  6.61  6.52  4.09   5408
# 26963   0.33      Ideal     H      IF   61.9   55.0  4.44  4.42  2.74   1114
# 26964   0.51    Premium     E     VS2   61.7   58.0  5.12  5.15  3.17   1656
# 26965   0.27  Very Good     F    VVS2   61.8   56.0  4.19  4.20  2.60    682
# 26966   1.25    Premium     J     SI1   62.0   58.0  6.90  6.88  4.27   5166
#
# [26967 rows x 10 columns]

# %% [markdown]
# ### 1. chechking the descriptive stats(5 pt summary i.e, min,max,25%,50%,75%)
# ### 2. comparing mean and median (to check if there are any outliers present in a column)
# ### 3.if there are any categorical columns check the number of unique values present and check its top and frequency.

# %%
df.describe(include='all').T
# Out:
#            count unique    top   freq         mean          std    min    25%  \
# carat    26967.0    NaN    NaN    NaN     0.798375     0.477745    0.2    0.4
# cut        26967      5  Ideal  10816          NaN          NaN    NaN    NaN
# color      26967      7      G   5661          NaN          NaN    NaN    NaN
# clarity    26967      8    SI1   6571          NaN          NaN    NaN    NaN
# depth    26270.0    NaN    NaN    NaN    61.745147      1.41286   50.8   61.0
# table    26967.0    NaN    NaN    NaN     57.45608     2.232068   49.0   56.0
# x        26967.0    NaN    NaN    NaN     5.729854     1.128516    0.0   4.71
# y        26967.0    NaN    NaN    NaN     5.733569     1.166058    0.0   4.71
# z        26967.0    NaN    NaN    NaN     3.538057     0.720624    0.0    2.9
# price    26967.0    NaN    NaN    NaN  3939.518115  4024.864666  326.0  945.0
#
#             50%     75%      max
# carat       0.7    1.05      4.5
# cut         NaN     NaN      NaN
# color       NaN     NaN      NaN
# clarity     NaN     NaN      NaN
# depth      61.8    62.5     73.6
# table      57.0    59.0     79.0
# x          5.69    6.55    10.23
# y          5.71    6.54     58.9
# z          3.52    4.04     31.8
# price    2375.0  5360.0  18818.0

# %%
df[(df['x']==0) | (df['y']==0) | (df['z']==0) ]
# Out:
#        carat      cut color clarity  depth  table     x     y    z  price
# 5821    0.71     Good     F     SI2   64.1   60.0  0.00  0.00  0.0   2130
# 6034    2.02  Premium     H     VS2   62.7   53.0  8.02  7.95  0.0  18207
# 6215    0.71     Good     F     SI2   64.1   60.0  0.00  0.00  0.0   2130
# 10827   2.20  Premium     H     SI1   61.2   59.0  8.42  8.37  0.0  17265
# 12498   2.18  Premium     H     SI2   59.4   61.0  8.49  8.45  0.0  12631
# 12689   1.10  Premium     G     SI2   63.0   59.0  6.50  6.47  0.0   3696
# 17506   1.14     Fair     G     VS1   57.5   67.0  0.00  0.00  0.0   6381
# 18194   1.01  Premium     H      I1   58.1   59.0  6.66  6.60  0.0   3167
# 23758   1.12  Premium     G      I1   60.4   59.0  6.71  6.67  0.0   2383

# %% [markdown]
# ### As dimensions cant be zero we will replace these values with medain

# %%
df['x'].replace(0,df['x'].median(),inplace=True)
df['y'].replace(0,df['y'].median(),inplace=True)
df['z'].replace(0,df['z'].median(),inplace=True)

# %%
### We can confirm that there are no  0 dimension values

# %%
df[df['x'] == 0]
# Out:
# Empty DataFrame
# Columns: [carat, cut, color, clarity, depth, table, x, y, z, price]
# Index: []

# %%
df[df['y'] == 0]
# Out:
# Empty DataFrame
# Columns: [carat, cut, color, clarity, depth, table, x, y, z, price]
# Index: []

# %%
df[df['z'] == 0]
# Out:
# Empty DataFrame
# Columns: [carat, cut, color, clarity, depth, table, x, y, z, price]
# Index: []

# %% [markdown]
# ### Either impute or drop null values
# ### outliers should be imputed with mean
# ### Null values present in categorical column use mode for imputation
# ### If there are large percantage of missing values present in the column then drop it, else try to impute it.

# %%
df.isnull().sum() #we have missing values in only one column i.e, depth
# Out:
# carat        0
# cut          0
# color        0
# clarity      0
# depth      697
# table        0
# x            0
# y            0
# z            0
# price        0
# dtype: int64

# %% [markdown]
# ### Check the percentage of missing columns

# %%
for i in df.columns:
    y = df[i].isnull().sum()/df.shape[0]
    print('Precentage of missing values is {} % in {} '.format(round(
        (y)*100,2),i))
# Out:
# Precentage of missing values is 0.0 % in carat
# Precentage of missing values is 0.0 % in cut
# Precentage of missing values is 0.0 % in color
# Precentage of missing values is 0.0 % in clarity
# Precentage of missing values is 2.58 % in depth
# Precentage of missing values is 0.0 % in table
# Precentage of missing values is 0.0 % in x
# Precentage of missing values is 0.0 % in y
# Precentage of missing values is 0.0 % in z
# Precentage of missing values is 0.0 % in price

# %% [markdown]
# ## Assigning median to missing values in depth column

# %%
m = df['depth'].median()
m
# Out:
# 61.8

# %%
df['depth'] = df['depth'].fillna(m)

# %%
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %%
df['cut'].value_counts()
# Out:
# Ideal        10816
# Premium       6899
# Very Good     6030
# Good          2441
# Fair           781
# Name: cut, dtype: int64

# %% [markdown]
# ## This describes this is categorical ordinal data

# %%
df.groupby('cut').median().T
# Out:
# /var/folders/bf/f89y356d061dpv04rhvw5mpw0000gn/T/ipykernel_73858/656423284.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('cut').median().T
# cut       Fair     Good    Ideal  Premium  Very Good
# carat     1.00     0.84     0.54     0.83       0.72
# depth    64.90    63.30    61.80    61.50      62.10
# table    58.00    58.00    56.00    59.00      58.00
# x         6.19     6.01     5.23     6.08       5.74
# y         6.12     6.02     5.25     6.04       5.78
# z         3.99     3.70     3.23     3.70       3.56
# price  3348.00  3098.00  1761.00  3121.00    2637.00

# %%
df.groupby('color').median().T
# Out:
# /var/folders/bf/f89y356d061dpv04rhvw5mpw0000gn/T/ipykernel_73858/2826860742.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('color').median().T
# color        D        E        F        G        H        I        J
# carat     0.53     0.53     0.70     0.70     0.90     1.01     1.11
# depth    61.80    61.80    61.80    61.80    61.90    61.90    61.90
# table    57.00    57.00    57.00    57.00    57.00    57.00    58.00
# x         5.21     5.22     5.62     5.65     6.13     6.37     6.65
# y         5.22     5.23     5.62     5.65     6.13     6.36     6.65
# z         3.21     3.22     3.45     3.49     3.80     3.94     4.11
# price  1800.50  1698.00  2278.00  2274.00  3413.00  3749.00  4234.00

# %%
df.groupby('clarity').median().T
# Out:
# /var/folders/bf/f89y356d061dpv04rhvw5mpw0000gn/T/ipykernel_73858/648690855.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('clarity').median().T
# clarity       I1        IF      SI1      SI2      VS1      VS2     VVS1  \
# carat       1.12     0.350     0.76     1.01     0.57     0.64     0.38
# depth      62.10    61.700    61.90    61.90    61.80    61.80    61.80
# table      58.00    56.000    57.00    58.00    57.00    57.00    57.00
# x           6.66     4.570     5.86     6.43     5.33     5.55     4.67
# y           6.62     4.585     5.86     6.42     5.34     5.55     4.70
# z           4.13     2.800     3.61     3.98     3.28     3.40     2.87
# price    3459.00  1063.500  2799.00  4077.00  1949.00  2066.00  1066.00
#
# clarity     VVS2
# carat       0.43
# depth      61.80
# table      57.00
# x           4.85
# y           4.87
# z           2.99
# price    1253.00

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
def outliers_per(col):
    Q1 = np.quantile(df[col],.25)
    Q3 = np.quantile(df[col],.75)
    IQR = Q3-Q1
    lower_range = Q1-(1.5*IQR)
    upper_range = Q3+(1.5*IQR)
    upper_count = df[df[col] > upper_range][col].count()
    upper_percentage = (upper_count/df.shape[0])*100
    lower_count = df[df[col] < lower_range][col].count()
    lower_percentage = (lower_count/df.shape[0])*100
    return print('Outlier percentage of {col} upper range is {upper}% and lower range is {lower}%\n'.format(col=col,upper=round(upper_percentage,2),lower=round(lower_percentage,2)))

# %%
for i in df.select_dtypes(exclude='object').columns:
    outliers_per(i)
# Out:
# Outlier percentage of carat upper range is 2.45% and lower range is 0.0%
#
# Outlier percentage of depth upper range is 1.92% and lower range is 3.34%
#
# Outlier percentage of table upper range is 1.15% and lower range is 0.03%
#
# Outlier percentage of x upper range is 0.04% and lower range is 0.0%
#
# Outlier percentage of y upper range is 0.04% and lower range is 0.0%
#
# Outlier percentage of z upper range is 0.05% and lower range is 0.0%
#
# Outlier percentage of price upper range is 6.6% and lower range is 0.0%

# %% [markdown]
# ## Replacing outliers with their upper and lower range

# %%
def replace_outlier(col):
    Q1, Q3 = np.quantile(col, [.25, .75])
    IQR = Q3 - Q1
    LL = Q1 - 1.5*IQR
    UL = Q3 + 1.5*IQR
    return LL, UL #Winsorization - UL - Capping, LL - Flooring

# %%
for i in df.select_dtypes(exclude='object'):
    LL, UL = replace_outlier(df[i])
    df[i] = np.where(df[i]> UL, UL, df[i])
    df[i] = np.where(df[i]< LL, LL, df[i])#Winsorization - Capping and Flooring

# %% [markdown]
# # Data visualisation
# ## Univariate Analysis
# ### Data visualisation for categorical data

# %%
for col in df.select_dtypes(include='object'):
    sns.countplot(x=df[col])
    plt.show()

# %% [markdown]
# ### Data visualisation for Numerical data

# %%
def uni_plot(columns):
    plt.figure(figsize=(15,10))
    plt.subplot(2,2,1)
    sns.histplot(data=df,x=columns,kde=True,bins=20)
    plt.title('Histogram of {}'.format(columns))
    plt.subplot(2,2,2)
    sns.boxplot(data=df,x=columns)
    plt.title('Boxplot of {}'.format(columns))
    plt.show()

# %%
for i in df .select_dtypes(exclude='object'):
    uni_plot(i)

# %% [markdown]
# ## Bivariate and multivariate

# %%
# Scatter plot for 'carat' vs. 'price'
plt.figure(figsize=(8, 6))
sns.scatterplot(x='carat', y='price', data=df)
plt.title('Carat vs. Price')
plt.xlabel('Carat')
plt.ylabel('Price')
plt.show()

# Pairplot for multiple numeric variables
sns.pairplot(df[['carat', 'depth', 'table', 'price']])
plt.show()

# %%
# Boxplot for 'cut' vs. 'price'
plt.figure(figsize=(8, 6))
sns.boxplot(x='cut', y='price', data=df)
plt.title('Cut vs. Price')
plt.xlabel('Cut')
plt.ylabel('Price')
plt.show()

# Bar plot for 'color' vs. 'price'
plt.figure(figsize=(8, 6))
sns.barplot(x='color', y='price', data=df)
plt.title('Color vs. Price')
plt.xlabel('Color')
plt.ylabel('Price')
plt.show()

# %%
cross_tab = pd.crosstab(df['cut'], df['color'])
print(cross_tab)


stacked_data = cross_tab.stack().reset_index().rename(columns={0: 'Count'})
plt.figure(figsize=(8, 6))
sns.barplot(x=stacked_data['cut'], y=stacked_data['Count'], hue=stacked_data['color'])
plt.title('Cut vs. Color')
plt.xlabel('Cut')
plt.ylabel('Count')
plt.show()
# Out:
# color         D     E     F     G     H     I    J
# cut
# Fair         74   100   148   147   150    94   68
# Good        311   491   454   419   352   253  161
# Ideal      1409  1966  1893  2470  1552  1073  453
# Premium     808  1174  1167  1471  1161   711  407
# Very Good   742  1186  1067  1154   887   640  354

# %%
plt.figure(figsize=(8, 6))
sns.lmplot(x='carat', y='price', data=df, hue='cut')
plt.title('Carat vs. Price by Cut')
plt.xlabel('Carat')
plt.ylabel('Price')
plt.show()

# %%
# Calculate the correlation matrix
correlation_matrix = df[['carat', 'depth', 'table', 'price']].corr()

# Plotting the correlation matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.heatmap(df.corr(),annot=True,cbar=False,mask=np.triu(df.corr(),+1))
plt.show()
# Out:
# /var/folders/bf/f89y356d061dpv04rhvw5mpw0000gn/T/ipykernel_73858/3285274156.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,cbar=False,mask=np.triu(df.corr(),+1))

# %%
sns.boxplot(data=df,y='price',x='clarity')
plt.show()

# %% [markdown]
# ### Normal distribution

# %%
import numpy as np
from scipy import stats

plt.figure(figsize=(8, 6))
sns.histplot(df['price'], kde=True, bins=30)
plt.title('Distribution of Price')
plt.show()

# %%
p_value = stats.shapiro(df['price']).pvalue

if p_value > 0.05:
    print("The 'price' column appears to be normally distributed (p-value: {:.4f})".format(p_value))
else:
    print("The 'price' column does not appear to be normally distributed (p-value: {:.4f})".format(p_value))
# Out:
# The 'price' column does not appear to be normally distributed (p-value: 0.0000)
# /Users/pavansai/anaconda3/lib/python3.11/site-packages/scipy/stats/_morestats.py:1816: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %%
transformed_price, _ = stats.boxcox(df['price'])

plt.figure(figsize=(8, 6))
sns.histplot(transformed_price, kde=True, bins=30)
plt.title('Transformed Distribution of Price')
plt.show()

# %% [markdown]
# # Insights

# %% [markdown]
# ### 1. Is there a relationship between diamond cut and price?

# %%
avg_price_by_cut = df.groupby('cut')['price'].mean()
avg_price_by_cut
# Out:
# cut
# Fair         4377.907810
# Good         3773.801721
# Ideal        3282.754993
# Premium      4284.055443
# Very Good    3832.066003
# Name: price, dtype: float64

# %% [markdown]
# #### yes, there is relationship b/w the diamond cut and price. Price ranges according to the cut i.e, Fair type cut has the highest price and Ideal type cut has lowest price

# %% [markdown]
# ### 2. How does carat size vary across different diamond cuts?

# %%
sns.boxplot(data=df, x='cut', y='carat')
plt.xlabel('Cut')
plt.ylabel('Carat Size')
plt.title('Carat size distribution by cut')
plt.show()

# %% [markdown]
# #### Fair type cut have median carat size as 1.<br>Premium type cut have median carat size as 0.8.<br>For the best cut i.e, Fair has highest carat size and the worst cut that is ideal has least carat value.

# %% [markdown]
# #### 3. What is the typical depth percentage for different clarity levels?

# %%
sns.boxplot(data=df, x='clarity', y='depth')
plt.xlabel('Clarity')
plt.ylabel('Depth Percentage')
plt.title('Depth percentage by clarity')
plt.show()

# %% [markdown]
# #### Almost all clarity types has median depth percentage as 62.

# %% [markdown]
# #### 4. How are diamond color and cut related?

# %%
table_1 = df.pivot_table(values='price',index='color',columns='cut',aggfunc='mean')
table_1
# Out:
# cut           Fair         Good        Ideal      Premium    Very Good
# color
# D      4347.222973  3375.667203  2454.311568  3507.410272  3506.163073
# E      4005.380000  3173.743381  2544.076806  3299.414395  3124.911467
# F      3899.746622  3454.014317  3162.494189  4147.516281  3523.828491
# G      4022.411565  4077.479714  3576.293927  4195.581237  3691.588388
# H      5156.903333  3893.646307  3657.288338  4845.365202  4394.184893
# I      4584.627660  4762.201581  4171.888164  5375.013361  4987.710156
# J      4764.205882  4669.083851  4578.152318  5870.377150  4773.574859

# %% [markdown]
# #### Fair cut and H color is the best and Ideal cut with E color is worst

# %% [markdown]
# ### Hypothesis Testing

# %% [markdown]
# Hypotheses:
# #### 	Null Hypothesis (H0): The mean price of cubic zirconia is the same across all 'cut' categories.<br>
# #### 	Alternative Hypothesis (H1): The mean price of cubic zirconia is different across 'cut' categories.
# Test Conducted:
# We'll perform an Analysis of Variance (ANOVA) test to examine if there's a statistically significant difference in the mean prices among different 'cut' categories.

# %%
from scipy.stats import f_oneway

cut_categories = df['cut'].unique()

cut_data = {category: df['price'][df['cut'] == category] for category in cut_categories}

f_statistic, p_value = f_oneway(*cut_data.values())

alpha = 0.05

if p_value < alpha:
    print("Reject the null hypothesis. There is a statistically significant difference in mean prices among 'cut' categories.")
else:
    print("Fail to reject the null hypothesis. There is no statistically significant difference in mean prices among 'cut' categories.")
# Out:
# Reject the null hypothesis. There is a statistically significant difference in mean prices among 'cut' categories.
